# %%
import pandas as pd
import sqlite3

from urllib3.util.proxy import connection_requires_http_tunnel

with sqlite3.connect('chinook.db') as connection:
    data=pd.read_sql("Select * from customers", con=connection)
data.head(10)
# Out:
#    CustomerId  FirstName     LastName  \
# 0           1       Luís    Gonçalves
# 1           2     Leonie       Köhler
# 2           3   François     Tremblay
# 3           4      Bjørn       Hansen
# 4           5  František  Wichterlová
# 5           6     Helena         Holý
# 6           7     Astrid       Gruber
# 7           8       Daan      Peeters
# 8           9       Kara      Nielsen
# 9          10    Eduardo      Martins
#
#                                             Company  \
# 0  Embraer - Empresa Brasileira de Aeronáutica S.A.
# 1                                              None
# 2                                              None
# 3                                              None
# 4                                  JetBrains s.r.o.
# 5                                              None
# 6                                              None
# 7                                              None
# 8                                              None
# ...

# %%
jsonfile=pd.read_json('iris.json')

jsonfile.shape
# Out:
# (150, 5)

# %%
jsonfile.dtypes
# Out:
# sepalLength    float64
# sepalWidth     float64
# petalLength    float64
# petalWidth     float64
# species         object
# dtype: object

# %%
titanic=pd.read_excel('titanic.xlsx')
titanic.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
movies=pd.read_csv('movie.csv')
movies.sample(10)
# Out:
#                 color     director_name  num_critic_for_reviews  duration  \
# 1857  Black and White  Steven Spielberg                   174.0     185.0
# 2351            Color     Michael Dowse                   136.0      97.0
# 4719            Color   Jean-Luc Godard                    96.0     110.0
# 2199            Color      Edgar Wright                   427.0     109.0
# 2534            Color      Clare Kilner                    46.0     101.0
# 2202            Color   Jim Field Smith                   180.0     104.0
# 3713            Color   Jeremy Saulnier                   322.0      95.0
# 3125            Color     Jason Bateman                   126.0      89.0
# 340             Color      Joe Johnston                   198.0      92.0
# 991             Color      Peter Webber                   209.0     131.0
#
#       director_facebook_likes  actor_3_facebook_likes       actor_2_name  \
# 1857                  14000.0                   212.0     Embeth Davidtz
# ...

# %%
jsonfile=pd.read_json('iris.json')
newones=[column.lower() for column in jsonfile.columns ]
jsonfile.columns=newones
jsonfile.dtypes
a=jsonfile[['sepallength','sepalwidth']]
a
# Out:
#      sepallength  sepalwidth
# 0            5.1         3.5
# 1            4.9         3.0
# 2            4.7         3.2
# 3            4.6         3.1
# 4            5.0         3.6
# ..           ...         ...
# 145          6.7         3.0
# 146          6.3         2.5
# 147          6.5         3.0
# 148          6.2         3.4
# 149          5.9         3.0
#
# [150 rows x 2 columns]

# %%
titanic=pd.read_excel('titanic.xlsx')
titanic[(titanic["Age"]>30)].sort_values(by=['Age'], ascending=True)
# a.
# titanic.dtypes
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 814          815         0       3            Tomlin, Mr. Ernest Portage
# 767          768         0       3                    Mangan, Miss. Mary
# 637          638         0       2                   Collyer, Mr. Harvey
# 797          798         1       3                      Osman, Mrs. Mara
# 673          674         1       2                 Wilhelms, Mr. Charles
# ..           ...       ...     ...                                   ...
# 116          117         0       3                  Connors, Mr. Patrick
# 493          494         0       1               Artagaveytia, Mr. Ramon
# 96            97         0       1             Goldschmidt, Mr. George B
# 851          852         0       3                   Svensson, Mr. Johan
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
#
#         Sex   Age  SibSp  Parch      Ticket     Fare Cabin Embarked
# ...

# %%
titanic.value_counts('Sex')
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
movies=pd.read_csv('movie.csv')
movies[(movies["duration"]>120)].sort_values(by=['duration'], ascending=True)
# Out:
#       color        director_name  num_critic_for_reviews  duration  \
# 1547  Color      Martin Scorsese                   163.0     121.0
# 964   Color       Clint Eastwood                    76.0     121.0
# 1822  Color         Andy Tennant                    92.0     121.0
# 3408  Color         Guy Hamilton                   136.0     121.0
# 163   Color            Rob Cohen                   145.0     121.0
# ...     ...                  ...                     ...       ...
# 3254  Color  Chatrichalerm Yukol                    31.0     300.0
# 1134  Color       Michael Cimino                   102.0     325.0
# 1487  Color      Taylor Hackford                    12.0     330.0
# 2436  Color                  NaN                   108.0     334.0
# 1694  Color                  NaN                    16.0     511.0
#
#       director_facebook_likes  actor_3_facebook_likes  \
# 1547                  17000.0                   245.0
# ...

# %%
movies[(movies["duration"]>120)].sort_values(by=['duration'], ascending=True).sort_values(by=['director_facebook_likes'],ascending=False)
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 3     Color  Christopher Nolan                   813.0     164.0
# 97    Color  Christopher Nolan                   642.0     148.0
# 96    Color  Christopher Nolan                   712.0     169.0
# 1222  Color  Christopher Nolan                   341.0     130.0
# 120   Color  Christopher Nolan                   478.0     128.0
# ...     ...                ...                     ...       ...
# 3799  Color                NaN                     2.0     199.0
# 3582  Color                NaN                    10.0     240.0
# 2687  Color                NaN                     9.0     286.0
# 2436  Color                NaN                   108.0     334.0
# 1694  Color                NaN                    16.0     511.0
#
#       director_facebook_likes  actor_3_facebook_likes  \
# 3                     22000.0                 23000.0
# 97                    22000.0                 23000.0
# ...

# %%
jsonfile.select_dtypes('number').mean()
# Out:
# sepallength    5.843333
# sepalwidth     3.057333
# petallength    3.758000
# petalwidth     1.199333
# dtype: float64

# %%
jsonfile.select_dtypes('number').std()
# Out:
# sepallength    0.828066
# sepalwidth     0.435866
# petallength    1.765298
# petalwidth     0.762238
# dtype: float64

# %%
jsonfile.select_dtypes('number').median()
# Out:
# sepallength    5.80
# sepalwidth     3.00
# petallength    4.35
# petalwidth     1.30
# dtype: float64

# %%
import numpy as np
titanic["Age"].describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
titanic["Age"].max()

# %%
titanic["Age"].min()
# Out:
# np.float64(0.42)

# %%
titanic["Age"].sum()
# Out:
# np.float64(21205.17)

# %%
movies['director_facebook_likes'].describe()
# Out:
# count     4814.000000
# mean       691.014541
# std       2832.954125
# min          0.000000
# 25%          7.000000
# 50%         48.000000
# 75%        189.750000
# max      23000.000000
# Name: director_facebook_likes, dtype: float64
